# %% [markdown]
# ###

# %% [markdown]
# #### Q3 - Q6

# %% [markdown]
# ![hw10_1.jpg](attachment:hw10_1.jpg)

# %% [markdown]
# ![hw10_2.jpg](attachment:hw10_2.jpg)

# %% [markdown]
# ![hw10_3.jpg](attachment:hw10_3.jpg)
